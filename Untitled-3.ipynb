# %%
# !python test_finance_mcp.py
# Out:
# ...
# Starting Finance MCP Server...
# ...
# ✓ Server started
#
# ...
# TEST 1A: Get Stock Price - AAPL
# ...
# Symbol: AAPL
# Price: $278.28
# Change: 0.09%
#
# ...
# TEST 1B: Get Stock Price - IBM
# ...
# Symbol: IBM
# Price: $309.24
# Change: -0.48%
#
# ...
# TEST 1C: Get Stock Price - MSFT
# ...
# Symbol: MSFT
# Price: $478.53
# Change: -1.02%
#
# ...
# TEST 1D: Get Stock Price - Invalid Symbol
# ...
# Response: {'error': "Stock 'INVALID' not found"}
#
# ...
# TEST 2A: Scrape Finance News - Stock Topic
# ...
# Topic: Stock
# Content: Stocks (also capital stock, or sometimes interchangeably, shares) consist of all the shares[a] by which ownership of a corporation or company is divid...
#
# ...
# TEST 2B: Scrape Finance News - Invalid Topic
# ...
# Response: {'error': "Topic 'NotARealFinanceTopic' not found"}
#
# ...
# TEST 3A: Calculate Investment - Standard Case
# ...
# Initial: $5000
# Final: $10794.62
# Gain: $5794.62
#
# ...
# TEST 3B: Calculate Investment - Invalid Input
# ...
# Response: {'error': 'Invalid input'}
#
# ...
# ✓ ALL TESTS PASSED!
# ...
#
# ...
# TEST 4: LoRA Fine-Tuned Generation
# ...
#
# ...
